# %%
# 1. Import needed libraries
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

sns.set()

# %%
# 2. My Data
dataset = [
    [5, 20],
    [480, 90],
    [250, 50],
    [100, 33],
    [330, 95],
    [410, 12],
    [475, 44],
    [25, 67],
    [85, 21],
    [220, 88],
    [150, 70],
    [290, 45],
    [60, 110],
    [200, 80],
    [130, 40],
    [500, 30],
    [180, 65],
    [55, 75],
    [450, 40],
    [375, 60],
    [320, 120],
    [350, 50],
    [80, 130],
    [230, 55],
    [370, 80],
    [100, 90],
    [420, 55],
    [540, 20]
]


np_dataset = np.array(dataset)

# %%
np_dataset.shape
# Out:
# (28, 2)

# %%
np_dataset[:, 0] # X-axis
# Out:
# array([  5, 480, 250, 100, 330, 410, 475,  25,  85, 220, 150, 290,  60,
#        200, 130, 500, 180,  55, 450, 375, 320, 350,  80, 230, 370, 100,
#        420, 540])

# %%
np_dataset[:, 1] # Y-axis
# Out:
# array([ 20,  90,  50,  33,  95,  12,  44,  67,  21,  88,  70,  45, 110,
#         80,  40,  30,  65,  75,  40,  60, 120,  50, 130,  55,  80,  90,
#         55,  20])

# %%
# 3. Plot the data
plt.figure(figsize=(10, 6))
plt.title("My Data Scater Plot", fontweight='bold')
sns.scatterplot(x=np_dataset[:, 0], y=np_dataset[:, 1], color='blue', s=100, alpha=0.7)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
